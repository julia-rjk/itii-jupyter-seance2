# %%
class Point2D:
  def __init__(self,px,py):
    self.x=px
    self.y=py
  
  def getX(self):
    return self.x

myPoint2d = Point2D(0,0)
print(myPoint2d.getX())

# %%
#Ex1: Rectangle
#Ecrire une classe Rectangle en langage Python, permettant de 
#construire un rectangle dotée d’attributs longueur et largeur.
class Rectangle:
  def __init__(self,longueur, largeur):
    self.longueur = longueur
    self.largeur = largeur
  
  

    # Créer une méthode Perimetre() permettant de calculer le périmètre du rectangle et 
    def perimetre(self):
        return self.longueur*2 + self.largeur*2
    
    # une méthode Surface() permettant de calculer la surface du rectangle
    def surface(self):
        return self.longueur * self.largeur
    
    # Créer les getters et setters.
    def getLongueur(self):
        return self.longueur
    
    def getLargeur(self):
        return self.largeur
    
    def setLongueur(self, longueur):
        return self.longueur = longueur
    
    def setLargeur(self, largeur ):
        return self.largeur = largeur 
    

# Créer une classe fille Parallelepipede héritant de la classe Rectangle
# et dotée en plus d’un attribut hauteur et 
# d’une autre méthode Volume() permettant de calculer le volume du Parallélépipède.

class Parallelepipede(Rectangle):
    def __init__(self, longueur, largeur, hauteur):
        Rectangle.__init__(self, longueur, largeur)
        self.hauteur = hauteur
        
        def volument(self):
            return self.longueur * self.largeur * self.hauteur
        
# Déﬁnir une classe Vecteur2D avec un constructeur
# fournissant les coordonnées par défaut d’un vecteur du plan (par exemple : x = 0 et y = 0).
class Vecteur2D:
  def __init__(self,px = 0,py = 0):
    self.x=px
    self.y=py
  
    def getX(self):
        return self.x

    def getY(self):
        return self.y
    
    def setX(self, x):
        self.y = x

    def setY(self, y):
        self.y = y
        
#Enrichissez la classe Vecteur2D en lui ajoutant 
#une méthode d’affichage et 
    def affichage(self):
        print("Vecteur, x = " + self.x + " y = " + self.y )

# une méthode de surcharge d’addition de deux vecteurs du plan.
    def addition(self, vecteur):
        return self.x + vecteur.x, self.y + vecteur.y
    
# Ex3 : Pile et File 
# Implanter des classes Pile et File utilisant 
# les listes comme structure de données interne et respectant l’interface suivante
class Pile(object):
    def __init__(self):
        self.array = []
    
    def pop(self):
        
        pass
    def push(self, elt):
        
        pass

class File(object):
    def __init__(self):
        self.array = []
    
    def pop(self):
        
        pass
    def push(self, elt):
        
        pass
    
# Exercice 4
class Mandelbrot(object):
    def __init__(self):
        self.array = []
        
    def f(z,c):
        return pow(z,2)+c
    
    def itere(c):
        nb=0
        #...
        
    def f(x,y,a,b):
        return pow(x,2)-pow(y,2)+a, 2*x*y + b
    
    def iterer(a,b):
        nb=0
